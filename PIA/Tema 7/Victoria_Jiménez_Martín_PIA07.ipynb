# %% [markdown]
# # Apartado 1: Carga el dataset y prepara los datos
#
#
# * Abre el notebook CNN on MNIST y revisalo entero. En principio, es un modelo demasiado sencillo, así que ahora te animamos a que crees tu propio modelo.
# * Inicia un nuevo notebook, y carga el dataset desde Keras.
# * Prepara los datos para poder ser ingeridos por una capa convolucional.
#
# # Apartado 2: Crea el modelo convolucional.
#
# * Crea un modelo con una o varias capas Conv2D.
# * Utiliza también capas max-pooling o strides que mantengan las dimensiones de la red bajo control.
# * Recuerda añadir una capa neuronal interna y una capa neuronal de salida, con tantas neuronas como clases de salida necesitamos.
#
# # Apartado 3: Entrena y evalua el modelo.
#
# * Configura los parámetros del entrenamiento.
# * Entrena el modelo.
# * Evalua el modelo con los datos de test y obtén la precisión real.

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Carga de datos
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preparación de los datos
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Construcción del modelo
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compilación del modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenamiento del modelo
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.1)

# Evaluación del modelo
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 422/422 [==============================] - 25s 56ms/step - loss: 0.2272 - accuracy: 0.9351 - val_loss: 0.0744 - val_accuracy: 0.9808
# Epoch 2/10
# 422/422 [==============================] - 24s 58ms/step - loss: 0.0715 - accuracy: 0.9792 - val_loss: 0.0648 - val_accuracy: 0.9817
# Epoch 3/10
# 422/422 [==============================] - 24s 58ms/step - loss: 0.0486 - accuracy: 0.9854 - val_loss: 0.0512 - val_accuracy: 0.9857
# Epoch 4/10
# 422/422 [==============================] - 24s 58ms/step - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.0471 - val_accuracy: 0.9868
# Epoch 5/10
# 422/422 [==============================] - 24s 57ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.0535 - val_accuracy: 0.9853
# Epoch 6/10
# 422/422 [==============================] - 23s 56ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0545 - val_accuracy: 0.9875
# Epoch 7/10
# ...

# %% [markdown]
# * ¿Es peor, igual o mejor que la que conseguimos en la unidad 5?.
#
# El valor del test del modelo de la unidad 5, era de un 0,469, lo que implicaria una baja precisión de prueba lo que significa que el modelo ha aprendido las particularidades del conjunto de datos de entrenamiento tan bien que no ha generalizado efectivamente a nuevos datos. Y el valor de el siguiente modelo corresponde con un 0,986, que hace que tenga una alta precisión de validación, lo que significa que el modelo es capaz de generalizar bien los datos que ha visto durante el entrenamiento y que el modelo esta aprendiendo las características relevantes de los datos.
